# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat 18. June CET 2022
@author: Bjoern Kasper (urmel79)
Class to measure execution time of a program
"""
import time
import pandas as pd

class MeasExecTimeOfProgram():
    def __init__(self):
        self._startTime = 0
        self._stopTime = 0
        self._deltaTime = 0
        
        self._header = ["Time samples"]
        self._df_log_buffer = pd.DataFrame(columns=self._header)

    # internal function to add rows to dataframe
    def _dataframe_add_row(self, df=None, row=[]):
        if (df is None):
            return

        # add a row
        df.loc[-1] = row

        # shift the index
        df.index = df.index + 1

        # reset the index of dataframe and avoid the old index being added as a column
        df.reset_index(drop=True, inplace=True)
    
    # define a START function
    def start(self):
        self._startTime = time.time()
        return 0

    # define a STOP function
    def stop(self):
        self._stopTime = time.time()

        self._deltaTime = self._stopTime - self._startTime

        return self._deltaTime
    
    # define a INIT LOGGER function
    def initLogger(self):
        self._df_log_buffer = pd.DataFrame(columns=self._header)
        return 0
    
    # define a ADD SAMPLE function
    def addSample(self, deltaTime):
        # log incoming rows to buffer (dataframe)
        self._dataframe_add_row(self._df_log_buffer, deltaTime)
        return 0
        
    # define a GET LOG BUFFER function
    def getLogBuffer(self):
        return self._df_log_buffer
    
    # define a GET STATISTICS
    def getStatistics(self):
        return self._df_log_buffer['Time samples'].describe()

# %%
execTime = MeasExecTimeOfProgram()

execTime.initLogger()

while True:
    try:
        execTime.start()
        
        # main program = worker function
        # find sum to first 1 million numbers
        sum_x = 0
        for i in range(1000000):
            sum_x += i
            
        deltaTime = execTime.stop()
        print("Execution time was {} sec.".format(deltaTime))
        
        execTime.addSample(deltaTime)
        
        time.sleep(1)
        
    except:
        print("Keyboard Interrupt ^C detected.")
        print("Bye.")
        break
# Out:
# Execution time was 0.3664224147796631 sec.
# Execution time was 0.40177249908447266 sec.
# Execution time was 0.3832743167877197 sec.
# Execution time was 0.3471486568450928 sec.
# Execution time was 0.40813565254211426 sec.
# Execution time was 0.38431668281555176 sec.
# Execution time was 0.4077799320220947 sec.
# Execution time was 0.383880615234375 sec.
# Execution time was 0.4044671058654785 sec.
# Execution time was 0.386044979095459 sec.
# Execution time was 0.36365318298339844 sec.
# Execution time was 0.390155553817749 sec.
# Execution time was 0.3942568302154541 sec.
# Execution time was 0.38356637954711914 sec.
# Execution time was 0.4008939266204834 sec.
# Execution time was 0.3855912685394287 sec.
# Execution time was 0.3948085308074951 sec.
# Execution time was 0.4143671989440918 sec.
# Execution time was 0.3872373104095459 sec.
# Execution time was 0.379291296005249 sec.
# Execution time was 0.39421534538269043 sec.
# Execution time was 0.3971285820007324 sec.
# Execution time was 0.39679455757141113 sec.
# Execution time was 0.40475988388061523 sec.
# Execution time was 0.39197874069213867 sec.
# Execution time was 0.37957143783569336 sec.
# Execution time was 0.40071582794189453 sec.
# Execution time was 0.40164923667907715 sec.
# Execution time was 0.3908998966217041 sec.
# Execution time was 0.377335786819458 sec.
# Execution time was 0.3686051368713379 sec.
# Execution time was 0.4020678997039795 sec.
# Execution time was 0.387037992477417 sec.
# Execution time was 0.3964958190917969 sec.
# Execution time was 0.410656213760376 sec.
# Execution time was 0.4001789093017578 sec.
# Execution time was 0.39485812187194824 sec.
# Execution time was 0.3898494243621826 sec.
# Execution time was 0.41467952728271484 sec.
# Execution time was 0.3412759304046631 sec.
# Execution time was 0.38005709648132324 sec.
# Execution time was 0.39965391159057617 sec.
# Execution time was 0.39156508445739746 sec.
# Execution time was 0.4070425033569336 sec.
# Execution time was 0.3953557014465332 sec.
# Execution time was 0.39305615425109863 sec.
# Execution time was 0.4112257957458496 sec.
# Execution time was 0.4067246913909912 sec.
# Execution time was 0.40175747871398926 sec.
# Execution time was 0.38963794708251953 sec.
# Execution time was 0.3856167793273926 sec.
# Execution time was 0.40256547927856445 sec.
# Execution time was 0.382183313369751 sec.
# Execution time was 0.40561389923095703 sec.
# Execution time was 0.40667104721069336 sec.
# Execution time was 0.37598371505737305 sec.
# Execution time was 0.3970060348510742 sec.
# Execution time was 0.38590574264526367 sec.
# Execution time was 0.41414642333984375 sec.
# Execution time was 0.4094679355621338 sec.
# Execution time was 0.3870208263397217 sec.
# Execution time was 0.39394664764404297 sec.
# Execution time was 0.4041585922241211 sec.
# Execution time was 0.404735803604126 sec.
# Execution time was 0.3760650157928467 sec.
# Execution time was 0.3887343406677246 sec.
# Execution time was 0.40894174575805664 sec.
# Execution time was 0.40782713890075684 sec.
# Execution time was 0.38583803176879883 sec.
# Execution time was 0.37800002098083496 sec.
# Execution time was 0.37978506088256836 sec.
# Execution time was 0.38098764419555664 sec.
# Execution time was 0.39095377922058105 sec.
# Execution time was 0.39897942543029785 sec.
# Execution time was 0.41184210777282715 sec.
# Execution time was 0.4080991744995117 sec.
# Execution time was 0.3781137466430664 sec.
# Execution time was 0.39077281951904297 sec.
# Execution time was 0.4086573123931885 sec.
# Execution time was 0.39165329933166504 sec.
# Execution time was 0.3991572856903076 sec.
# Execution time was 0.3966512680053711 sec.
# Execution time was 0.3760972023010254 sec.
# Execution time was 0.412996768951416 sec.
# Execution time was 0.3859694004058838 sec.
# Execution time was 0.39412593841552734 sec.
# Execution time was 0.3981056213378906 sec.
# Execution time was 0.3973102569580078 sec.
# Execution time was 0.3956022262573242 sec.
# Execution time was 0.4222993850708008 sec.
# Execution time was 0.3919520378112793 sec.
# Execution time was 0.4025087356567383 sec.
# Execution time was 0.39549684524536133 sec.
# Execution time was 0.3311598300933838 sec.
# Execution time was 0.4059906005859375 sec.
# Execution time was 0.4048037528991699 sec.
# Execution time was 0.40085649490356445 sec.
# Execution time was 0.4002695083618164 sec.
# Execution time was 0.39396190643310547 sec.
# Keyboard Interrupt ^C detected.
# Bye.

# %%
execTime.getLogBuffer()
# Out:
#     Time samples
# 0       0.366422
# 1       0.401772
# 2       0.383274
# 3       0.347149
# 4       0.408136
# ..           ...
# 94      0.405991
# 95      0.404804
# 96      0.400856
# 97      0.400270
# 98      0.393962
#
# [99 rows x 1 columns]

# %%
execTime.getStatistics()
# Out:
# count    99.000000
# mean      0.393227
# std       0.014991
# min       0.331160
# 25%       0.385872
# 50%       0.394858
# 75%       0.403362
# max       0.422299
# Name: Time samples, dtype: float64
